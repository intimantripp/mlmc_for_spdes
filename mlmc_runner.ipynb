# %%
import numpy as np
from scipy.stats import norm

# %%
from mlmc.gbm_euler import gbm_euler
import numpy as np
np.random.seed(seed=42)
gbm_euler(N=150000)
# Out:
# l = 0
# l = 1
# l = 2
# l = 3
# l = 4
# l = 5
# l = 6
# l = 7
# l = 8
# l = 9
# l = 10
# Estimates of key MLMC Theorem parameters based on linear regression:
# alpha = 1.025432 (exponent for MLMC weak convergence)
# beta = 0.994959 (exponent for MLMC variance)
# gamma = 0.913072 (exponent for MLMC cost
# eps = 0.005
# Adding new level 3 with remaining error 2.377795 > eps/sqrt(2) = 0.003536
# New level 3 added, with 437139 samples and variance 0.636169
# Adding new level 4 with remaining error 0.036378 > eps/sqrt(2) = 0.003536
# New level 4 added, with 252909 samples and variance 0.337529
# Adding new level 5 with remaining error 0.012495 > eps/sqrt(2) = 0.003536
# New level 5 added, with 144039 samples and variance 0.177132
# Adding new level 6 with remaining error 0.005732 > eps/sqrt(2) = 0.003536
# New level 6 added, with 79734 samples and variance 0.089785
# eps = 0.01
# Adding new level 3 with remaining error 2.377330 > eps/sqrt(2) = 0.007071
# New level 3 added, with 108493 samples and variance 0.629655
# Adding new level 4 with remaining error 0.035223 > eps/sqrt(2) = 0.007071
# New level 4 added, with 63685 samples and variance 0.342357
# Adding new level 5 with remaining error 0.012031 > eps/sqrt(2) = 0.007071
# New level 5 added, with 35708 samples and variance 0.174740
# eps = 0.02
# Adding new level 3 with remaining error 2.381686 > eps/sqrt(2) = 0.014142
# New level 3 added, with 27239 samples and variance 0.631315
# Adding new level 4 with remaining error 0.035759 > eps/sqrt(2) = 0.014142
# New level 4 added, with 15888 samples and variance 0.339863
# eps = 0.05
# Adding new level 3 with remaining error 2.375685 > eps/sqrt(2) = 0.035355
# New level 3 added, with 4340 samples and variance 0.627891
# eps = 0.1
# Adding new level 3 with remaining error 2.390080 > eps/sqrt(2) = 0.070711
# New level 3 added, with 1151 samples and variance 0.687838
# l = 0
# l = 1
# l = 2
# l = 3
# l = 4
# l = 5
# l = 6
# l = 7
# l = 8
# l = 9
# l = 10
# Estimates of key MLMC Theorem parameters based on linear regression:
# alpha = 0.743245 (exponent for MLMC weak convergence)
# beta = 0.502427 (exponent for MLMC variance)
# gamma = 0.978924 (exponent for MLMC cost
# WARNING: kurtosis on finest level = 769.218981.
#                  indicates MLMC correction dominated by a few rare paths; for information                 on the connection to variance of sample variances see                 http://mathworld.wolfram.com/SampleVarianceDistribution.html
# eps = 0.005
# Adding new level 3 with remaining error 3.016664 > eps/sqrt(2) = 0.003536
# New level 3 added, with 366457 samples and variance 1.144995
# Adding new level 4 with remaining error 0.099379 > eps/sqrt(2) = 0.003536
# New level 4 added, with 307868 samples and variance 0.912295
# Adding new level 5 with remaining error 0.050917 > eps/sqrt(2) = 0.003536
# New level 5 added, with 242923 samples and variance 0.677501
# Adding new level 6 with remaining error 0.025561 > eps/sqrt(2) = 0.003536
# New level 6 added, with 185327 samples and variance 0.488714
# Adding new level 7 with remaining error 0.011685 > eps/sqrt(2) = 0.003536
# New level 7 added, with 138736 samples and variance 0.349443
# Adding new level 8 with remaining error 0.006138 > eps/sqrt(2) = 0.003536
# New level 8 added, with 105034 samples and variance 0.257485
# Adding new level 9 with remaining error 0.004085 > eps/sqrt(2) = 0.003536
# New level 9 added, with 77803 samples and variance 0.184868
# eps = 0.01
# Adding new level 3 with remaining error 3.018222 > eps/sqrt(2) = 0.007071
# New level 3 added, with 91426 samples and variance 1.144497
# Adding new level 4 with remaining error 0.097406 > eps/sqrt(2) = 0.007071
# New level 4 added, with 74980 samples and variance 0.881237
# Adding new level 5 with remaining error 0.048268 > eps/sqrt(2) = 0.007071
# New level 5 added, with 60185 samples and variance 0.669803
# Adding new level 6 with remaining error 0.025006 > eps/sqrt(2) = 0.007071
# New level 6 added, with 46426 samples and variance 0.491396
# Adding new level 7 with remaining error 0.012257 > eps/sqrt(2) = 0.007071
# New level 7 added, with 35193 samples and variance 0.358453
# Adding new level 8 with remaining error 0.011261 > eps/sqrt(2) = 0.007071
# New level 8 added, with 27703 samples and variance 0.278544
# eps = 0.02
# Adding new level 3 with remaining error 3.016107 > eps/sqrt(2) = 0.014142
# New level 3 added, with 21967 samples and variance 1.082638
# Adding new level 4 with remaining error 0.100078 > eps/sqrt(2) = 0.014142
# New level 4 added, with 19238 samples and variance 0.916785
# Adding new level 5 with remaining error 0.050042 > eps/sqrt(2) = 0.014142
# New level 5 added, with 15943 samples and variance 0.728789
# Adding new level 6 with remaining error 0.026195 > eps/sqrt(2) = 0.014142
# New level 6 added, with 12242 samples and variance 0.526749
# eps = 0.05
# Adding new level 3 with remaining error 3.009564 > eps/sqrt(2) = 0.035355
# New level 3 added, with 3654 samples and variance 1.142693
# Adding new level 4 with remaining error 0.094475 > eps/sqrt(2) = 0.035355
# New level 4 added, with 3088 samples and variance 0.915337
# Adding new level 5 with remaining error 0.053531 > eps/sqrt(2) = 0.035355
# New level 5 added, with 2377 samples and variance 0.661667
# Adding new level 6 with remaining error 0.060497 > eps/sqrt(2) = 0.035355
# New level 6 added, with 2348 samples and variance 0.693797
# Adding new level 7 with remaining error 0.038395 > eps/sqrt(2) = 0.035355
# New level 7 added, with 1568 samples and variance 0.407950
# eps = 0.1
# Adding new level 3 with remaining error 3.008465 > eps/sqrt(2) = 0.070711
# New level 3 added, with 1072 samples and variance 1.436637
# Adding new level 4 with remaining error 0.130800 > eps/sqrt(2) = 0.070711
# New level 4 added, with 802 samples and variance 0.952456
# Adding new level 5 with remaining error 0.071866 > eps/sqrt(2) = 0.070711
# New level 5 added, with 479 samples and variance 0.477464

# %%
from mlmc.mlmc_test import mlmc_test
from mlmc.gbm_euler_performant import gbm_l
S0 = 100
K = 100
T = 1
r = 0.05
sig = 0.2
M = 2
L = 10
N = 100000
N0 = 1000
Eps = [0.001, 0.005, 0.01, 0.05]
validation_value = 10.46
option = 1
output_path = "data/gbm_euler_1.csv"
mlmc_test(lambda l, N: gbm_l(l, N, option, S0, K, T, r, sig), M, N, L, N0, Eps, 
          validate=True, validation_value=validation_value,
          output_path=output_path)
# Out:
# l = 0
# l = 1
# l = 2
# l = 3
# l = 4
# l = 5
# l = 6
# l = 7
# l = 8
# l = 9
# l = 10
# Estimates of key MLMC Theorem parameters based on linear regression:
# alpha = 1.448706 (exponent for MLMC weak convergence)
# beta = 0.992737 (exponent for MLMC variance)
# gamma = 1.002251 (exponent for MLMC cost
# eps = 0.001
# Adding new level 3 with remaining error 0.791769 > eps/sqrt(2) = 0.000707
# New level 3 added, with 10935151 samples and variance 0.636764
# Adding new level 4 with remaining error 0.012068 > eps/sqrt(2) = 0.000707
# New level 4 added, with 6340545 samples and variance 0.339131
# Adding new level 5 with remaining error 0.005057 > eps/sqrt(2) = 0.000707
# New level 5 added, with 3598050 samples and variance 0.176875
# Adding new level 6 with remaining error 0.002254 > eps/sqrt(2) = 0.000707
# New level 6 added, with 2000924 samples and variance 0.090382
# Adding new level 7 with remaining error 0.000917 > eps/sqrt(2) = 0.000707
# New level 7 added, with 1098658 samples and variance 0.045766
# eps = 0.005
# Adding new level 3 with remaining error 0.791545 > eps/sqrt(2) = 0.003536
# New level 3 added, with 438472 samples and variance 0.639175
# Adding new level 4 with remaining error 0.012552 > eps/sqrt(2) = 0.003536
# New level 4 added, with 254219 samples and variance 0.340208
# Adding new level 5 with remaining error 0.006035 > eps/sqrt(2) = 0.003536
# New level 5 added, with 144212 samples and variance 0.177289
# eps = 0.01
# Adding new level 3 with remaining error 0.792329 > eps/sqrt(2) = 0.007071
# New level 3 added, with 109668 samples and variance 0.639342
# Adding new level 4 with remaining error 0.012102 > eps/sqrt(2) = 0.007071
# New level 4 added, with 63557 samples and variance 0.340166
# eps = 0.05
# Adding new level 3 with remaining error 0.789458 > eps/sqrt(2) = 0.035355
# New level 3 added, with 4267 samples and variance 0.607121
#
# Results saved to data/gbm_euler_1.csv
# (array([ 1.01668207e+01,  1.52775928e-01,  5.26600288e-02,  2.18929807e-02,
#          1.18848496e-02,  5.75326979e-03,  3.13184619e-03,  1.06392629e-03,
#          7.87560000e-04, -4.47258190e-06,  1.89423279e-04]),
#  array([10.16682067, 10.34454197, 10.40277561, 10.39854069, 10.47105454,
#         10.50542888, 10.51199686, 10.46279323, 10.47645325, 10.47923115,
#         10.52327935]),
#  array([1.62083376e+02, 2.42475371e+00, 1.27951305e+00, 6.76663107e-01,
#         3.55070383e-01, 1.80024999e-01, 9.08773487e-02, 4.57645605e-02,
#         2.30880605e-02, 1.13828571e-02, 5.73919577e-03]),
#  array([162.08337554, 187.5679035 , 199.86321346, 209.44071106,
#         213.25381183, 215.97879115, 216.61506521, 216.45384934,
#         215.9001602 , 216.92294357, 219.15527771]))

# %%
from mlmc.gbm_euler_performant import gbm_euler_performant
gbm_euler_performant()
# Out:
# l = 0
# l = 1
# l = 2
# l = 3
# l = 4
# l = 5
# l = 6
# l = 7
# l = 8
# l = 9
# l = 10
# Estimates of key MLMC Theorem parameters based on linear regression:
# alpha = 1.448706 (exponent for MLMC weak convergence)
# beta = 0.992737 (exponent for MLMC variance)
# gamma = 1.205093 (exponent for MLMC cost
# eps = 0.005
# Adding new level 3 with remaining error 0.791545 > eps/sqrt(2) = 0.003536
# New level 3 added, with 438472 samples and variance 0.639175
# Adding new level 4 with remaining error 0.012552 > eps/sqrt(2) = 0.003536
# New level 4 added, with 254219 samples and variance 0.340208
# Adding new level 5 with remaining error 0.006035 > eps/sqrt(2) = 0.003536
# New level 5 added, with 144212 samples and variance 0.177289
# eps = 0.01
# Adding new level 3 with remaining error 0.792329 > eps/sqrt(2) = 0.007071
# New level 3 added, with 109668 samples and variance 0.639342
# Adding new level 4 with remaining error 0.012102 > eps/sqrt(2) = 0.007071
# New level 4 added, with 63557 samples and variance 0.340166
# eps = 0.02
# Adding new level 3 with remaining error 0.791729 > eps/sqrt(2) = 0.014142
# New level 3 added, with 27672 samples and variance 0.647930
# eps = 0.05
# Adding new level 3 with remaining error 0.789458 > eps/sqrt(2) = 0.035355
# New level 3 added, with 4267 samples and variance 0.607121
# eps = 0.1
# Adding new level 3 with remaining error 0.795316 > eps/sqrt(2) = 0.070711
# New level 3 added, with 1018 samples and variance 0.564543

# %%
from mlmc.para import para
para()
# Out:
# l = 0
# l = 1
# l = 2
# l = 3
# l = 4
# l = 5
# l = 6
# Estimates of key MLMC Theorem parameters based on linear regression:
# alpha = 1.722581 (exponent for MLMC weak convergence)
# beta = 3.985390 (exponent for MLMC variance)
# gamma = 2.729524 (exponent for MLMC cost
# eps = 0.005
# Adding new level 3 with remaining error 0.165576 > eps/sqrt(2) = 0.003536
# New level 3 added, with 5432 samples and variance 0.009820
# Adding new level 4 with remaining error 0.007594 > eps/sqrt(2) = 0.003536
# New level 4 added, with 530 samples and variance 0.000615
# eps = 0.01
# Adding new level 3 with remaining error 0.165468 > eps/sqrt(2) = 0.007071
# New level 3 added, with 1341 samples and variance 0.009634
# Adding new level 4 with remaining error 0.008880 > eps/sqrt(2) = 0.007071
# New level 4 added, with 134 samples and variance 0.000622
# eps = 0.02
# Adding new level 3 with remaining error 0.166253 > eps/sqrt(2) = 0.014142
# New level 3 added, with 331 samples and variance 0.009389
# eps = 0.05
# Adding new level 3 with remaining error 0.167720 > eps/sqrt(2) = 0.035355
# New level 3 added, with 52 samples and variance 0.008851
# eps = 0.1
# Adding new level 3 with remaining error 0.162729 > eps/sqrt(2) = 0.070711
# New level 3 added, with 10 samples and variance 0.005928

# %%
from mlmc.stoch_heat_eqn import stoch_heat_eqn
stoch_heat_eqn()
# Out:
# l = 0
# l = 1
# l = 2
# l = 3
# l = 4
# l = 5
# l = 6
# Estimates of key MLMC Theorem parameters based on linear regression:
# alpha = 0.445976 (exponent for MLMC weak convergence)
# beta = 2.138359 (exponent for MLMC variance)
# gamma = 2.983396 (exponent for MLMC cost
# eps = 0.005
# Adding new level 3 with remaining error 0.121910 > eps/sqrt(2) = 0.003536
# New level 3 added, with 84 samples and variance 0.000413
# Adding new level 4 with remaining error 0.014393 > eps/sqrt(2) = 0.003536
# New level 4 added, with 18 samples and variance 0.000072
# Adding new level 5 with remaining error 0.006435 > eps/sqrt(2) = 0.003536
# New level 5 added, with 5 samples and variance 0.000015
# Adding new level 6 with remaining error 0.005235 > eps/sqrt(2) = 0.003536
# New level 6 added, with 2 samples and variance 0.000004
# eps = 0.01
# Adding new level 3 with remaining error 0.124011 > eps/sqrt(2) = 0.007071
# New level 3 added, with 27 samples and variance 0.000531
# Adding new level 4 with remaining error 0.012957 > eps/sqrt(2) = 0.007071
# New level 4 added, with 5 samples and variance 0.000070
# Adding new level 5 with remaining error 0.010629 > eps/sqrt(2) = 0.007071
# New level 5 added, with 1 samples and variance 0.000007
# Adding new level 6 with remaining error 0.008886 > eps/sqrt(2) = 0.007071
# New level 6 added, with 1 samples and variance 0.000001
# eps = 0.02
# Adding new level 3 with remaining error 0.121737 > eps/sqrt(2) = 0.014142
# New level 3 added, with 4 samples and variance 0.000282
# Adding new level 4 with remaining error 0.046885 > eps/sqrt(2) = 0.014142
# New level 4 added, with 2 samples and variance 0.000144
# Adding new level 5 with remaining error 0.037308 > eps/sqrt(2) = 0.014142
# New level 5 added, with 1 samples and variance 0.000014
# Adding new level 6 with remaining error 0.025059 > eps/sqrt(2) = 0.014142
# New level 6 added, with 1 samples and variance 0.000002
# eps = 0.05
# Adding new level 3 with remaining error 0.122086 > eps/sqrt(2) = 0.035355
# New level 3 added, with 1 samples and variance 0.000371
# eps = 0.1
# Adding new level 3 with remaining error 0.147924 > eps/sqrt(2) = 0.070711
# New level 3 added, with 1 samples and variance 0.000437

# %%
import numpy as np
from mlmc.stoch_heat_eqn_qoi import stoch_heat_eqn_qoi

## Calculate nth Fourier mode of the solution u ##

def nth_fourier_mode(n, u):
    # Calculates integral from 0 to 1 of 2*u(x,t)sin(n pi x) dx
    x = np.linspace(0, 1, u.shape[0])
    sin_basis = np.sin(n * np.pi * x)[:, np.newaxis]
    integrand = 2 * u * sin_basis
    fourier_mode = np.trapz(integrand, x, axis=0)
    return fourier_mode

def suspect_noise_coupling(dWf):
    num_rows = int(dWf.shape[0] / 2 - 0.5) # nf - 1 internal points for fine. Corresponds to (nf + 1) / 2 - 1 coarse internals
    dWc =  dWf[:-1, :].reshape(num_rows, 2, dWf.shape[1]).sum(axis=1) * 0.5 # sum of 2 fine adjacent increments, ignore final point
    return dWc

first_fourier = lambda u: nth_fourier_mode(1, u)
stoch_heat_eqn_qoi(qoi_fn=first_fourier, validation_value=0.0, noise_coupling=suspect_noise_coupling)
# Out:
# l = 0
# l = 1
# l = 2
# l = 3
# /var/folders/l5/rhh7z5c528b5hjwqy30m3vzr0000gn/T/ipykernel_49768/1520906711.py:11: DeprecationWarning: `trapz` is deprecated. Use `trapezoid` instead, or one of the numerical integration functions in `scipy.integrate`.
#   fourier_mode = np.trapz(integrand, x, axis=0)
# l = 4
# l = 5
# l = 6
# Estimates of key MLMC Theorem parameters based on linear regression:
# alpha = 0.478937 (exponent for MLMC weak convergence)
# beta = 2.044423 (exponent for MLMC variance)
# gamma = 2.896451 (exponent for MLMC cost
# eps = 0.005
# Adding new level 3 with remaining error 0.003878 > eps/sqrt(2) = 0.003536
# New level 3 added, with 477 samples and variance 0.002220
# Adding new level 4 with remaining error 0.003652 > eps/sqrt(2) = 0.003536
# New level 4 added, with 117 samples and variance 0.000485
# Adding new level 5 with remaining error 0.008108 > eps/sqrt(2) = 0.003536
# New level 5 added, with 27 samples and variance 0.000101
# Adding new level 6 with remaining error 0.006588 > eps/sqrt(2) = 0.003536
# New level 6 added, with 9 samples and variance 0.000032
# Adding new level 7 with remaining error 0.003571 > eps/sqrt(2) = 0.003536
# New level 7 added, with 2 samples and variance 0.000004
# eps = 0.01
# Adding new level 3 with remaining error 0.007201 > eps/sqrt(2) = 0.007071
# New level 3 added, with 119 samples and variance 0.002199
# eps = 0.02
# eps = 0.05
# eps = 0.1
# Adding new level 3 with remaining error 0.089707 > eps/sqrt(2) = 0.070711
# New level 3 added, with 2 samples and variance 0.002165
# (array([-8.96640528e-03, -2.98668557e-03,  8.72074596e-05, -3.37928663e-04,
#          1.09677945e-04,  1.46417445e-04,  2.51940150e-05]),
#  array([-0.00896641, -0.00455322,  0.00010519, -0.0064327 ,  0.01106297,
#         -0.00565747, -0.0039945 ]),
#  array([1.67703283e-01, 4.88120841e-02, 8.75885027e-03, 1.99621459e-03,
#         4.86299431e-04, 1.22279464e-04, 2.96285818e-05]),
#  array([0.16770328, 0.11272165, 0.10385757, 0.09898651, 0.09910978,
#         0.1008211 , 0.10005839]))

# %%
import numpy as np
from mlmc.stoch_heat_eqn_qoi import stoch_heat_eqn_qoi
def nth_fourier_mode(n, u):
    # Calculates integral from 0 to 1 of 2*u(x,t)sin(n pi x) dx
    x = np.linspace(0, 1, u.shape[0])
    sin_basis = np.sin(n * np.pi * x)[:, np.newaxis]
    integrand = 2 * u * sin_basis
    fourier_mode = np.trapz(integrand, x, axis=0)
    return fourier_mode

first_fourier_var = lambda u: nth_fourier_mode(1, u)**2
true_var = lambda n: (1 - np.exp(- 2 * n**2 * np.pi**2 * 0.25)) / (n**2 * np.pi**2)

stoch_heat_eqn_qoi(qoi_fn=first_fourier_var, validation_value=true_var(1))
# Out:
# l = 0
# l = 1
# l = 2
# l = 3
# /var/folders/l5/rhh7z5c528b5hjwqy30m3vzr0000gn/T/ipykernel_11985/3994078466.py:8: DeprecationWarning: `trapz` is deprecated. Use `trapezoid` instead, or one of the numerical integration functions in `scipy.integrate`.
#   fourier_mode = np.trapz(integrand, x, axis=0)
# l = 4
# l = 5
# l = 6
# Estimates of key MLMC Theorem parameters based on linear regression:
# alpha = 2.224088 (exponent for MLMC weak convergence)
# beta = 2.054866 (exponent for MLMC variance)
# gamma = 2.848111 (exponent for MLMC cost
# eps = 0.005
# eps = 0.01
# eps = 0.02
# eps = 0.05
# eps = 0.1
# (array([ 1.60504053e-01, -4.84923164e-02, -1.08672196e-02, -2.17482175e-03,
#         -7.64726001e-04,  1.02670237e-04, -2.24658181e-05]),
#  array([0.16050405, 0.11554539, 0.10019793, 0.10377687, 0.09887818,
#         0.10035408, 0.09744431]),
#  array([5.12621777e-02, 2.76008499e-02, 3.68881823e-03, 8.21229071e-04,
#         1.96797977e-04, 4.92345298e-05, 1.21647591e-05]),
#  array([0.05126218, 0.02763459, 0.02044996, 0.022019  , 0.02025849,
#         0.02003358, 0.01877776]))

# %%
from mlmc.stoch_heat_eqn_fine_coupling import stoch_heat_eqn_fine_coupling
from utils.she_qoi import nth_fourier_mode, analytic_fourier_mode_var

first_fm_var = lambda u: nth_fourier_mode(1, u)**2
true_value = analytic_fourier_mode_var(1)
stoch_heat_eqn_fine_coupling(qoi_fn=first_fm_var, validation_value=true_value)
# Out:
# l = 0
# l = 1
# l = 2
# l = 3
# l = 4
# l = 5
# l = 6
# Estimates of key MLMC Theorem parameters based on linear regression:
# alpha = 1.864103 (exponent for MLMC weak convergence)
# beta = 2.061473 (exponent for MLMC variance)
# gamma = 2.901892 (exponent for MLMC cost
# eps = 0.005
# Adding new level 3 with remaining error 0.005114 > eps/sqrt(2) = 0.003536
# New level 3 added, with 199 samples and variance 0.000894
# eps = 0.01
# eps = 0.02
# eps = 0.05
# eps = 0.1
# (array([ 1.69314818e-01, -5.03726895e-02, -1.06437726e-02, -2.38661922e-03,
#         -4.36191853e-04, -1.85303448e-04, -5.97435139e-05]),
#  array([0.16931482, 0.11450149, 0.10318488, 0.10122582, 0.10103355,
#         0.10123673, 0.10026044]),
#  array([5.90789486e-02, 2.86441962e-02, 3.77626591e-03, 8.29703404e-04,
#         2.07141164e-04, 5.03811062e-05, 1.20938195e-05]),
#  array([0.05907895, 0.02697434, 0.02101771, 0.0208981 , 0.01964589,
#         0.02110652, 0.01991304]))

# %%
from mlmc.dean_kawasaki import dean_kawasaki_eqn, dean_kawasaki_eqn_l
# _, mc_estimates = dean_kawasaki_eqn_l(5, 10000)
# print("We are done with the MC estimate. These are the MC estimate: \n", mc_estimates[0]/10000)
# validation_value = mc_estimates[0]/10000
validation_value =  0.4999752067807876
dean_kawasaki_eqn(validation_value)
# Out:
# l = 0
# l = 1
# l = 2
# l = 3
# l = 4
# l = 5
# Estimates of key MLMC Theorem parameters based on linear regression:
# alpha = 1.762210 (exponent for MLMC weak convergence)
# beta = 1.965833 (exponent for MLMC variance)
# gamma = 3.044678 (exponent for MLMC cost
# eps = 0.0005
# Adding new level 3 with remaining error 0.019252 > eps/sqrt(2) = 0.000354
# New level 3 added, with 315326 samples and variance 0.017561
# Adding new level 4 with remaining error 0.005672 > eps/sqrt(2) = 0.000354
# New level 4 added, with 96731 samples and variance 0.004752
# Adding new level 5 with remaining error 0.001547 > eps/sqrt(2) = 0.000354
# New level 5 added, with 27483 samples and variance 0.001242
# Adding new level 6 with remaining error 0.000401 > eps/sqrt(2) = 0.000354
# New level 6 added, with 7178 samples and variance 0.000303
# eps = 0.001
# Adding new level 3 with remaining error 0.019203 > eps/sqrt(2) = 0.000707
# New level 3 added, with 79435 samples and variance 0.017719
# Adding new level 4 with remaining error 0.005665 > eps/sqrt(2) = 0.000707
# New level 4 added, with 23975 samples and variance 0.004698
# Adding new level 5 with remaining error 0.001552 > eps/sqrt(2) = 0.000707
# New level 5 added, with 6840 samples and variance 0.001236
# eps = 0.005
# Adding new level 3 with remaining error 0.019333 > eps/sqrt(2) = 0.003536
# New level 3 added, with 3314 samples and variance 0.018612
# Adding new level 4 with remaining error 0.005682 > eps/sqrt(2) = 0.003536
# New level 4 added, with 972 samples and variance 0.004748
# eps = 0.01
# Adding new level 3 with remaining error 0.018850 > eps/sqrt(2) = 0.007071
# New level 3 added, with 821 samples and variance 0.018437
# eps = 0.02
# Adding new level 3 with remaining error 0.018790 > eps/sqrt(2) = 0.014142
# New level 3 added, with 197 samples and variance 0.017478
# eps = 0.05
# eps = 0.1

# %%
from mlmc.stoch_heat_eqn_fe import stoch_heat_eqn_fe
from utils.she_qoi import nth_fourier_mode, analytic_fourier_mode_var
first_fm_var = lambda u: nth_fourier_mode(1, u)**2
true_value = analytic_fourier_mode_var(1)
stoch_heat_eqn_fe(qoi_fn=first_fm_var, validation_value=true_value)
# Out:
# l = 0
# l = 1
# l = 2
# l = 3
# l = 4
# l = 5
# l = 6
# Estimates of key MLMC Theorem parameters based on linear regression:
# alpha = 1.995230 (exponent for MLMC weak convergence)
# beta = 4.003691 (exponent for MLMC variance)
# gamma = 2.901089 (exponent for MLMC cost
# eps = 0.001
# Adding new level 3 with remaining error 0.002350 > eps/sqrt(2) = 0.000707
# New level 3 added, with 105 samples and variance 0.000007
# eps = 0.005
# eps = 0.01
# eps = 0.02
# eps = 0.05
# eps = 0.1
# (array([ 1.09888988e-01, -7.18054625e-03, -1.95543396e-03, -4.78410412e-04,
#         -1.40399122e-04, -3.08370074e-05, -7.64692025e-06]),
#  array([0.10988899, 0.1030467 , 0.10016884, 0.10071895, 0.10123819,
#         0.10032933, 0.10017118]),
#  array([2.50250199e-02, 2.15357090e-03, 1.08282365e-04, 6.66550838e-06,
#         4.26292280e-07, 2.60842120e-08, 1.62978666e-09]),
#  array([0.02502502, 0.0209177 , 0.02064413, 0.02058069, 0.02064815,
#         0.02048355, 0.01927979]))

# %%
from mlmc.stoch_heat_eqn_fine_coupling import stoch_heat_eqn_fine_coupling
from utils.she_qoi import nth_fourier_mode

first_fm = lambda u: nth_fourier_mode(1, u)
true_value = 0
stoch_heat_eqn_fine_coupling(qoi_fn=first_fm, validation_value=true_value)
# Out:
# l = 0
# l = 1
# l = 2
# l = 3
# l = 4
# l = 5
# l = 6
# Estimates of key MLMC Theorem parameters based on linear regression:
# alpha = 0.803544 (exponent for MLMC weak convergence)
# beta = 2.050303 (exponent for MLMC variance)
# gamma = 2.944017 (exponent for MLMC cost
# eps = 0.005
# Adding new level 3 with remaining error 0.004181 > eps/sqrt(2) = 0.003536
# New level 3 added, with 456 samples and variance 0.002094
# Adding new level 4 with remaining error 0.005844 > eps/sqrt(2) = 0.003536
# New level 4 added, with 116 samples and variance 0.000486
# Adding new level 5 with remaining error 0.003671 > eps/sqrt(2) = 0.003536
# New level 5 added, with 28 samples and variance 0.000110
# eps = 0.01
# eps = 0.02
# eps = 0.05
# eps = 0.1
# (array([-2.36863968e-04, -1.53524151e-03,  1.97261302e-04, -2.05441420e-04,
#          2.38854191e-05,  2.22273396e-05,  3.70244500e-05]),
#  array([-0.00023686,  0.00124195, -0.00142721, -0.00195028,  0.00435857,
#          0.00270511, -0.0042048 ]),
#  array([1.68733672e-01, 4.96101167e-02, 8.96992648e-03, 2.01014749e-03,
#         4.88833187e-04, 1.21990911e-04, 2.98693569e-05]),
#  array([0.16873367, 0.11642098, 0.1020544 , 0.10021714, 0.10275415,
#         0.10275304, 0.10052987]))

# %%
from mlmc.dean_kawasaki_cc import dean_kawasaki_eqn_cc
dean_kawasaki_eqn_cc(validation_value=0.5)
# Out:
# l = 0
# l = 1
# l = 2
# l = 3
# l = 4
# Estimates of key MLMC Theorem parameters based on linear regression:
# alpha = 1.447003 (exponent for MLMC weak convergence)
# beta = 1.836973 (exponent for MLMC variance)
# gamma = 3.001853 (exponent for MLMC cost
# eps = 0.01
# Adding new level 3 with remaining error 0.034161 > eps/sqrt(2) = 0.007071
# New level 3 added, with 873 samples and variance 0.019995
# Adding new level 4 with remaining error 0.012196 > eps/sqrt(2) = 0.007071
# New level 4 added, with 261 samples and variance 0.005231
# eps = 0.02
# Adding new level 3 with remaining error 0.033689 > eps/sqrt(2) = 0.014142
# New level 3 added, with 203 samples and variance 0.018441
# eps = 0.05
# Adding new level 3 with remaining error 0.056149 > eps/sqrt(2) = 0.035355
# New level 3 added, with 32 samples and variance 0.018051
# eps = 0.1

# %%
from mlmc.dean_kawasaki import dean_kawasaki_eqn
dean_kawasaki_eqn(validation_value=0.5)
# Out:
# l = 0
# l = 1
# l = 2
# l = 3
# l = 4
# Estimates of key MLMC Theorem parameters based on linear regression:
# alpha = 1.875183 (exponent for MLMC weak convergence)
# beta = 1.963479 (exponent for MLMC variance)
# gamma = 2.880000 (exponent for MLMC cost
# eps = 0.005
# Adding new level 3 with remaining error 0.016063 > eps/sqrt(2) = 0.003536
# New level 3 added, with 3201 samples and variance 0.017850
# Adding new level 4 with remaining error 0.004634 > eps/sqrt(2) = 0.003536
# New level 4 added, with 948 samples and variance 0.004624
# eps = 0.01
# Adding new level 3 with remaining error 0.016079 > eps/sqrt(2) = 0.007071
# New level 3 added, with 774 samples and variance 0.017137
# eps = 0.02
# Adding new level 3 with remaining error 0.026115 > eps/sqrt(2) = 0.014142
# New level 3 added, with 252 samples and variance 0.023234
# eps = 0.05
# eps = 0.1

# %%
from mlmc.stoch_heat_eqn_fe import stoch_heat_eqn_fe
stoch_heat_eqn_fe()
# Out:
# l = 0
# l = 1
# l = 2
# l = 3
# l = 4
# l = 5
# l = 6
# Estimates of key MLMC Theorem parameters based on linear regression:
# alpha = 1.173459 (exponent for MLMC weak convergence)
# beta = 2.960159 (exponent for MLMC variance)
# gamma = 2.916427 (exponent for MLMC cost
# eps = 0.1
# eps = 0.05
# eps = 0.02
# eps = 0.01
# Adding new level 3 with remaining error 0.009299 > eps/sqrt(2) = 0.007071
# New level 3 added, with 2 samples and variance 0.000017
# eps = 0.005
# Adding new level 3 with remaining error 0.008482 > eps/sqrt(2) = 0.003536
# New level 3 added, with 5 samples and variance 0.000016
# eps = 0.001
# Adding new level 3 with remaining error 0.008657 > eps/sqrt(2) = 0.000707
# New level 3 added, with 128 samples and variance 0.000017
# Adding new level 4 with remaining error 0.002613 > eps/sqrt(2) = 0.000707
# New level 4 added, with 20 samples and variance 0.000002
# Adding new level 5 with remaining error 0.001025 > eps/sqrt(2) = 0.000707
# New level 5 added, with 4 samples and variance 0.000000
# (array([0.05464134, 0.01725728, 0.00620078, 0.00245152, 0.00106681,
#         0.00049337, 0.00023678]),
#  array([0.05464134, 0.0721769 , 0.07760877, 0.08133959, 0.08241968,
#         0.0830059 , 0.08261842]),
#  array([6.09747464e-03, 1.01077394e-03, 1.45442422e-04, 1.91370587e-05,
#         2.46159278e-06, 3.10190580e-07, 4.00249755e-08]),
#  array([0.00609747, 0.00571873, 0.00532749, 0.00564417, 0.00561111,
#         0.00572394, 0.00555938]))

# %%
from mlmc.dean_kawasaki_fe import run_dean_kawasaki_eqn_fe
run_dean_kawasaki_eqn_fe()
# Out:
# l = 0
# l = 1
# l = 2
# l = 3
# l = 4
# Estimates of key MLMC Theorem parameters based on linear regression:
# alpha = 2.079139 (exponent for MLMC weak convergence)
# beta = 4.198741 (exponent for MLMC variance)
# gamma = 3.039344 (exponent for MLMC cost
# eps = 0.005
# Adding new level 3 with remaining error 0.183906 > eps/sqrt(2) = 0.003536
# New level 3 added, with 15070 samples and variance 0.034754
# Adding new level 4 with remaining error 0.043542 > eps/sqrt(2) = 0.003536
# New level 4 added, with 1455 samples and variance 0.002022
# Adding new level 5 with remaining error 0.009916 > eps/sqrt(2) = 0.003536
# New level 5 added, with 129 samples and variance 0.000110
# eps = 0.01
# Adding new level 3 with remaining error 0.184127 > eps/sqrt(2) = 0.007071
# New level 3 added, with 3799 samples and variance 0.035110
# Adding new level 4 with remaining error 0.043615 > eps/sqrt(2) = 0.007071
# New level 4 added, with 360 samples and variance 0.001976
# Adding new level 5 with remaining error 0.009888 > eps/sqrt(2) = 0.007071
# New level 5 added, with 33 samples and variance 0.000113
# eps = 0.02
# Adding new level 3 with remaining error 0.184701 > eps/sqrt(2) = 0.014142
# New level 3 added, with 953 samples and variance 0.035055
# Adding new level 4 with remaining error 0.043723 > eps/sqrt(2) = 0.014142
# New level 4 added, with 89 samples and variance 0.001936
# eps = 0.05
# Adding new level 3 with remaining error 0.187592 > eps/sqrt(2) = 0.035355
# New level 3 added, with 156 samples and variance 0.035767
# Adding new level 4 with remaining error 0.045474 > eps/sqrt(2) = 0.035355
# New level 4 added, with 16 samples and variance 0.002266
# eps = 0.1
# Adding new level 3 with remaining error 0.189287 > eps/sqrt(2) = 0.070711
# New level 3 added, with 38 samples and variance 0.033774
