# %%
import numpy as np
from scipy.stats import norm

# %%
from mlmc.gbm_euler import gbm_euler
import numpy as np
np.random.seed(seed=42)
gbm_euler()
# Out:
# l = 0
# l = 1
# l = 2
# l = 3
# l = 4
# l = 5
# l = 6
# l = 7
# l = 8
# l = 9
# l = 10
# Estimates of key MLMC Theorem parameters based on linear regression:
# alpha = 1.052304 (exponent for MLMC weak convergence)
# beta = 0.992373 (exponent for MLMC variance)
# gamma = 1.028976 (exponent for MLMC cost
# eps = 0.005
# Adding new level 3 with remaining error 2.209503 > eps/sqrt(2) = 0.003536
# New level 3 added, with 439035 samples and variance 0.640694
# Adding new level 4 with remaining error 0.033422 > eps/sqrt(2) = 0.003536
# New level 4 added, with 253212 samples and variance 0.338067
# Adding new level 5 with remaining error 0.011983 > eps/sqrt(2) = 0.003536
# New level 5 added, with 144471 samples and variance 0.177970
# Adding new level 6 with remaining error 0.004289 > eps/sqrt(2) = 0.003536
# New level 6 added, with 79708 samples and variance 0.089693
# eps = 0.01
# Adding new level 3 with remaining error 2.209670 > eps/sqrt(2) = 0.007071
# ...

# %%
from mlmc.para import para
para()
# Out:
# l = 0
# l = 1
# l = 2
# l = 3
# l = 4
# l = 5
# l = 6
# Estimates of key MLMC Theorem parameters based on linear regression:
# alpha = 1.655446 (exponent for MLMC weak convergence)
# beta = 3.987364 (exponent for MLMC variance)
# gamma = 2.765028 (exponent for MLMC cost
# eps = 0.005
# Adding new level 3 with remaining error 0.194466 > eps/sqrt(2) = 0.003536
# New level 3 added, with 5370 samples and variance 0.009659
# Adding new level 4 with remaining error 0.008564 > eps/sqrt(2) = 0.003536
# New level 4 added, with 528 samples and variance 0.000614
# eps = 0.01
# Adding new level 3 with remaining error 0.194671 > eps/sqrt(2) = 0.007071
# New level 3 added, with 1331 samples and variance 0.009542
# Adding new level 4 with remaining error 0.009632 > eps/sqrt(2) = 0.007071
# New level 4 added, with 128 samples and variance 0.000579
# eps = 0.02
# Adding new level 3 with remaining error 0.195069 > eps/sqrt(2) = 0.014142
# New level 3 added, with 324 samples and variance 0.009126
# ...

# %%
from mlmc.stoch_heat_eqn import stoch_heat_eqn
stoch_heat_eqn()
# Out:
# l = 0
# l = 1
# l = 2
# l = 3
# l = 4
# l = 5
# l = 6
# Estimates of key MLMC Theorem parameters based on linear regression:
# alpha = -0.010000 (exponent for MLMC weak convergence)
# beta = 0.017518 (exponent for MLMC variance)
# gamma = 2.694209 (exponent for MLMC cost
# eps = 0.005
# Estimated alpha: 0.500000
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 2
#       1 from mlmc.stoch_heat_eqn import stoch_heat_eqn
# ----> 2 stoch_heat_eqn()
#
# File ~/Documents/Academic/Oxford/Dissertation/MLMC_understanding/mlmc/stoch_heat_eqn.py:15, in stoch_heat_eqn()
#      13 validation_value = 0.08527441178994156
#      14 validation_value = 4.138060043680517
# ---> 15 mlmc_test(lambda l, N: stoch_heat_eqn_l(l, N), M, N, L, N0, Eps, nvert,validate=True, validation_value=validation_value)
#
# ...

# %%
from mlmc.stoch_heat_eqn_debug import stoch_heat_eqn
stoch_heat_eqn() # sigma = delta t / delta x
# Out:
# l = 0
# l = 1
# l = 2
# l = 3
# l = 4
# l = 5
# l = 6
# Estimates of key MLMC Theorem parameters based on linear regression:
# alpha = 1.047145 (exponent for MLMC weak convergence)
# beta = 2.221301 (exponent for MLMC variance)
# gamma = 2.925965 (exponent for MLMC cost
# eps = 0.005
# Adding new level 3 with remaining error 0.037272 > eps/sqrt(2) = 0.003536
# New level 3 added, with 70 samples and variance 0.000321
# Adding new level 4 with remaining error 0.017168 > eps/sqrt(2) = 0.003536
# New level 4 added, with 10 samples and variance 0.000033
# Adding new level 5 with remaining error 0.008073 > eps/sqrt(2) = 0.003536
# New level 5 added, with 2 samples and variance 0.000003
# Adding new level 6 with remaining error 0.003626 > eps/sqrt(2) = 0.003536
# New level 6 added, with 1 samples and variance 0.000000
# eps = 0.01
# Adding new level 3 with remaining error 0.032340 > eps/sqrt(2) = 0.007071
# New level 3 added, with 18 samples and variance 0.000333
# ...

# %%
from mlmc.stoch_heat_eqn_debug import stoch_heat_eqn
stoch_heat_eqn() # sigma = delta t / delta x - and include the half factor
