# %%
import numpy as np
from scipy.stats import norm

# %%
from mlmc.gbm_euler import gbm_euler
import numpy as np
np.random.seed(seed=42)
gbm_euler()
# Out:
# l = 0
# l = 1
# l = 2
# l = 3
# l = 4
# l = 5
# l = 6
# l = 7
# l = 8
# l = 9
# l = 10
# Estimates of key MLMC Theorem parameters based on linear regression:
# alpha = 1.052304 (exponent for MLMC weak convergence)
# beta = 0.992373 (exponent for MLMC variance)
# gamma = 1.007248 (exponent for MLMC cost
# eps = 0.005
# Adding new level 3 with remaining error 2.209503 > eps/sqrt(2) = 0.003536
# New level 3 added, with 439035 samples and variance 0.640694
# Adding new level 4 with remaining error 0.033422 > eps/sqrt(2) = 0.003536
# New level 4 added, with 253212 samples and variance 0.338067
# Adding new level 5 with remaining error 0.011983 > eps/sqrt(2) = 0.003536
# New level 5 added, with 144471 samples and variance 0.177970
# Adding new level 6 with remaining error 0.004289 > eps/sqrt(2) = 0.003536
# New level 6 added, with 79708 samples and variance 0.089693
# eps = 0.01
# Adding new level 3 with remaining error 2.209670 > eps/sqrt(2) = 0.007071
# New level 3 added, with 108922 samples and variance 0.632306
# Adding new level 4 with remaining error 0.033732 > eps/sqrt(2) = 0.007071
# New level 4 added, with 63606 samples and variance 0.340931
# Adding new level 5 with remaining error 0.010979 > eps/sqrt(2) = 0.007071
# New level 5 added, with 36279 samples and variance 0.179346
# eps = 0.02
# Adding new level 3 with remaining error 2.206347 > eps/sqrt(2) = 0.014142
# New level 3 added, with 27108 samples and variance 0.627423
# Adding new level 4 with remaining error 0.035275 > eps/sqrt(2) = 0.014142
# New level 4 added, with 15814 samples and variance 0.337745
# eps = 0.05
# Adding new level 3 with remaining error 2.206693 > eps/sqrt(2) = 0.035355
# New level 3 added, with 4435 samples and variance 0.652584
# eps = 0.1
# Adding new level 3 with remaining error 2.217663 > eps/sqrt(2) = 0.070711
# New level 3 added, with 1167 samples and variance 0.704807
# l = 0
# l = 1
# l = 2
# l = 3
# l = 4
# l = 5
# l = 6
# l = 7
# l = 8
# l = 9
# l = 10
# Estimates of key MLMC Theorem parameters based on linear regression:
# alpha = 0.853040 (exponent for MLMC weak convergence)
# beta = 0.502998 (exponent for MLMC variance)
# gamma = 1.077402 (exponent for MLMC cost
# WARNING: kurtosis on finest level = 699.295927.
#                  indicates MLMC correction dominated by a few rare paths; for information                 on the connection to variance of sample variances see                 http://mathworld.wolfram.com/SampleVarianceDistribution.html
# eps = 0.005
# Adding new level 3 with remaining error 2.165026 > eps/sqrt(2) = 0.003536
# New level 3 added, with 360509 samples and variance 1.123620
# Adding new level 4 with remaining error 0.069712 > eps/sqrt(2) = 0.003536
# New level 4 added, with 307658 samples and variance 0.914600
# Adding new level 5 with remaining error 0.036195 > eps/sqrt(2) = 0.003536
# New level 5 added, with 245416 samples and variance 0.689755
# Adding new level 6 with remaining error 0.019172 > eps/sqrt(2) = 0.003536
# New level 6 added, with 188287 samples and variance 0.500366
# Adding new level 7 with remaining error 0.009027 > eps/sqrt(2) = 0.003536
# New level 7 added, with 139038 samples and variance 0.349254
# Adding new level 8 with remaining error 0.004334 > eps/sqrt(2) = 0.003536
# New level 8 added, with 104336 samples and variance 0.253510
# eps = 0.01
# Adding new level 3 with remaining error 2.166086 > eps/sqrt(2) = 0.007071
# New level 3 added, with 89050 samples and variance 1.106336
# Adding new level 4 with remaining error 0.068517 > eps/sqrt(2) = 0.007071
# New level 4 added, with 76875 samples and variance 0.914684
# Adding new level 5 with remaining error 0.034690 > eps/sqrt(2) = 0.007071
# New level 5 added, with 63592 samples and variance 0.726404
# Adding new level 6 with remaining error 0.018424 > eps/sqrt(2) = 0.007071
# New level 6 added, with 47263 samples and variance 0.501892
# Adding new level 7 with remaining error 0.010804 > eps/sqrt(2) = 0.007071
# New level 7 added, with 33627 samples and variance 0.332291
# eps = 0.02
# Adding new level 3 with remaining error 2.159569 > eps/sqrt(2) = 0.014142
# New level 3 added, with 22259 samples and variance 1.103216
# Adding new level 4 with remaining error 0.069179 > eps/sqrt(2) = 0.014142
# New level 4 added, with 18546 samples and variance 0.871033
# Adding new level 5 with remaining error 0.033482 > eps/sqrt(2) = 0.014142
# New level 5 added, with 16147 samples and variance 0.743248
# Adding new level 6 with remaining error 0.018996 > eps/sqrt(2) = 0.014142
# New level 6 added, with 11621 samples and variance 0.490158
# eps = 0.05
# Adding new level 3 with remaining error 2.169378 > eps/sqrt(2) = 0.035355
# New level 3 added, with 3469 samples and variance 1.051540
# Adding new level 4 with remaining error 0.073777 > eps/sqrt(2) = 0.035355
# New level 4 added, with 3511 samples and variance 1.096882
# Adding new level 5 with remaining error 0.038263 > eps/sqrt(2) = 0.035355
# New level 5 added, with 2529 samples and variance 0.708976
# eps = 0.1
# Adding new level 3 with remaining error 2.166303 > eps/sqrt(2) = 0.070711
# New level 3 added, with 840 samples and variance 1.007093
# Adding new level 4 with remaining error 0.072600 > eps/sqrt(2) = 0.070711
# New level 4 added, with 627 samples and variance 0.684004

# %%
from mlmc.para import para
para()
# Out:
# l = 0
# l = 1
# l = 2
# l = 3
# l = 4
# l = 5
# l = 6
# Estimates of key MLMC Theorem parameters based on linear regression:
# alpha = 1.747558 (exponent for MLMC weak convergence)
# beta = 3.984288 (exponent for MLMC variance)
# gamma = 2.731157 (exponent for MLMC cost
# eps = 0.005
# Adding new level 3 with remaining error 0.156094 > eps/sqrt(2) = 0.003536
# New level 3 added, with 5374 samples and variance 0.009653
# Adding new level 4 with remaining error 0.007501 > eps/sqrt(2) = 0.003536
# New level 4 added, with 520 samples and variance 0.000597
# eps = 0.01
# Adding new level 3 with remaining error 0.156110 > eps/sqrt(2) = 0.007071
# New level 3 added, with 1356 samples and variance 0.009783
# Adding new level 4 with remaining error 0.008523 > eps/sqrt(2) = 0.007071
# New level 4 added, with 133 samples and variance 0.000619
# eps = 0.02
# Adding new level 3 with remaining error 0.155862 > eps/sqrt(2) = 0.014142
# New level 3 added, with 337 samples and variance 0.009695
# eps = 0.05
# Adding new level 3 with remaining error 0.155432 > eps/sqrt(2) = 0.035355
# New level 3 added, with 48 samples and variance 0.008122
# eps = 0.1
# Adding new level 3 with remaining error 0.157674 > eps/sqrt(2) = 0.070711
# New level 3 added, with 14 samples and variance 0.009755

# %%
from mlmc.stoch_heat_eqn import stoch_heat_eqn
stoch_heat_eqn()
# Out:
# l = 0
# l = 1
# l = 2
# l = 3
# l = 4
# l = 5
# l = 6
# Estimates of key MLMC Theorem parameters based on linear regression:
# alpha = 0.385509 (exponent for MLMC weak convergence)
# beta = 2.146609 (exponent for MLMC variance)
# gamma = 2.930501 (exponent for MLMC cost
# eps = 0.005
# Adding new level 3 with remaining error 0.156631 > eps/sqrt(2) = 0.003536
# New level 3 added, with 69 samples and variance 0.000328
# Adding new level 4 with remaining error 0.025294 > eps/sqrt(2) = 0.003536
# New level 4 added, with 17 samples and variance 0.000070
# Adding new level 5 with remaining error 0.011387 > eps/sqrt(2) = 0.003536
# New level 5 added, with 5 samples and variance 0.000016
# Adding new level 6 with remaining error 0.018101 > eps/sqrt(2) = 0.003536
# New level 6 added, with 2 samples and variance 0.000007
# Adding new level 7 with remaining error 0.012654 > eps/sqrt(2) = 0.003536
# New level 7 added, with 1 samples and variance 0.000002
# Adding new level 8 with remaining error 0.006995 > eps/sqrt(2) = 0.003536
# New level 8 added, with 1 samples and variance 0.000000
# eps = 0.01
# Adding new level 3 with remaining error 0.155030 > eps/sqrt(2) = 0.007071
# New level 3 added, with 27 samples and variance 0.000560
# Adding new level 4 with remaining error 0.025841 > eps/sqrt(2) = 0.007071
# New level 4 added, with 5 samples and variance 0.000066
# Adding new level 5 with remaining error 0.018368 > eps/sqrt(2) = 0.007071
# New level 5 added, with 1 samples and variance 0.000007
# Adding new level 6 with remaining error 0.011187 > eps/sqrt(2) = 0.007071
# New level 6 added, with 1 samples and variance 0.000001
# eps = 0.02
# Adding new level 3 with remaining error 0.155502 > eps/sqrt(2) = 0.014142
# New level 3 added, with 5 samples and variance 0.000388
# Adding new level 4 with remaining error 0.026029 > eps/sqrt(2) = 0.014142
# New level 4 added, with 1 samples and variance 0.000062
# Adding new level 5 with remaining error 0.034682 > eps/sqrt(2) = 0.014142
# New level 5 added, with 1 samples and variance 0.000006
# Adding new level 6 with remaining error 0.034822 > eps/sqrt(2) = 0.014142
# New level 6 added, with 1 samples and variance 0.000001
# Adding new level 7 with remaining error 0.026656 > eps/sqrt(2) = 0.014142
# New level 7 added, with 1 samples and variance 0.000000
# Adding new level 8 with remaining error 0.020406 > eps/sqrt(2) = 0.014142
# New level 8 added, with 1 samples and variance 0.000000
# eps = 0.05
# Adding new level 3 with remaining error 0.155360 > eps/sqrt(2) = 0.035355
# New level 3 added, with 1 samples and variance 0.000417
# eps = 0.1
# Adding new level 3 with remaining error 0.182064 > eps/sqrt(2) = 0.070711
# New level 3 added, with 1 samples and variance 0.000415

# %%
# Base run
# %%timeit
from mlmc.stoch_heat_eqn_qoi import stoch_heat_eqn_qoi
stoch_heat_eqn_qoi()
# Out:
# l = 0
# l = 1
# l = 2
# l = 3
# l = 4
# l = 5
# l = 6
# Estimates of key MLMC Theorem parameters based on linear regression:
# alpha = 0.596084 (exponent for MLMC weak convergence)
# beta = 2.151137 (exponent for MLMC variance)
# gamma = 2.931036 (exponent for MLMC cost
# eps = 0.005
# Adding new level 3 with remaining error 0.072534 > eps/sqrt(2) = 0.003536
# New level 3 added, with 67 samples and variance 0.000315
# Adding new level 4 with remaining error 0.007993 > eps/sqrt(2) = 0.003536
# New level 4 added, with 19 samples and variance 0.000081
# Adding new level 5 with remaining error 0.007849 > eps/sqrt(2) = 0.003536
# New level 5 added, with 6 samples and variance 0.000022
# Adding new level 6 with remaining error 0.008191 > eps/sqrt(2) = 0.003536
# New level 6 added, with 2 samples and variance 0.000007
# Adding new level 7 with remaining error 0.004597 > eps/sqrt(2) = 0.003536
# New level 7 added, with 1 samples and variance 0.000001
# eps = 0.01
# Adding new level 3 with remaining error 0.073422 > eps/sqrt(2) = 0.007071
# New level 3 added, with 15 samples and variance 0.000281
# Adding new level 4 with remaining error 0.007752 > eps/sqrt(2) = 0.007071
# New level 4 added, with 3 samples and variance 0.000032
# eps = 0.02
# Adding new level 3 with remaining error 0.076818 > eps/sqrt(2) = 0.014142
# New level 3 added, with 6 samples and variance 0.000410
# Adding new level 4 with remaining error 0.015538 > eps/sqrt(2) = 0.014142
# New level 4 added, with 1 samples and variance 0.000046
# eps = 0.05
# Adding new level 3 with remaining error 0.066846 > eps/sqrt(2) = 0.035355
# New level 3 added, with 1 samples and variance 0.000352
# Adding new level 4 with remaining error 0.094879 > eps/sqrt(2) = 0.035355
# New level 4 added, with 1 samples and variance 0.000040
# Adding new level 5 with remaining error 0.062767 > eps/sqrt(2) = 0.035355
# New level 5 added, with 1 samples and variance 0.000004
# Adding new level 6 with remaining error 0.041523 > eps/sqrt(2) = 0.035355
# New level 6 added, with 1 samples and variance 0.000001
# eps = 0.1
# (array([ 0.08242373,  0.01159905, -0.0031964 , -0.00351731, -0.00237646,
#         -0.00127916, -0.0006716 ]),
#  array([0.08242373, 0.09634561, 0.09336213, 0.08842357, 0.08467156,
#         0.08371501, 0.08345647]),
#  array([1.38599403e-02, 7.49353924e-03, 1.74860940e-03, 3.43400834e-04,
#         8.06163295e-05, 1.86750861e-05, 4.33689428e-06]),
#  array([0.01385994, 0.00857911, 0.00679875, 0.00604912, 0.00525873,
#         0.00557757, 0.00554085]))

# %%
import numpy as np
from mlmc.stoch_heat_eqn_qoi import stoch_heat_eqn_qoi

## Calculate nth Fourier mode of the solution u ##

def nth_fourier_mode(n, u):
    # Calculates integral from 0 to 1 of 2*u(x,t)sin(n pi x) dx
    x = np.linspace(0, 1, u.shape[0])
    sin_basis = np.sin(n * np.pi * x)[:, np.newaxis]
    integrand = 2 * u * sin_basis
    fourier_mode = np.trapz(integrand, x, axis=0)
    return fourier_mode

def suspect_noise_coupling(dWf):
    num_rows = int(dWf.shape[0] / 2 - 0.5) # nf - 1 internal points for fine. Corresponds to (nf + 1) / 2 - 1 coarse internals
    dWc =  dWf[:-1, :].reshape(num_rows, 2, dWf.shape[1]).sum(axis=1) * 0.5 # sum of 2 fine adjacent increments, ignore final point
    return dWc

first_fourier = lambda u: nth_fourier_mode(1, u)
stoch_heat_eqn_qoi(qoi_fn=first_fourier, validation_value=0.0, noise_coupling=suspect_noise_coupling)
# Out:
# l = 0
# l = 1
# l = 2
# l = 3
# /var/folders/l5/rhh7z5c528b5hjwqy30m3vzr0000gn/T/ipykernel_37483/1520906711.py:11: DeprecationWarning: `trapz` is deprecated. Use `trapezoid` instead, or one of the numerical integration functions in `scipy.integrate`.
#   fourier_mode = np.trapz(integrand, x, axis=0)
# l = 4
# l = 5
# l = 6
# Estimates of key MLMC Theorem parameters based on linear regression:
# alpha = 1.214202 (exponent for MLMC weak convergence)
# beta = 2.031716 (exponent for MLMC variance)
# gamma = 2.890528 (exponent for MLMC cost
# eps = 0.005
# eps = 0.01
# eps = 0.02
# eps = 0.05
# eps = 0.1
# (array([-7.77175779e-04, -4.06555908e-03, -2.23523825e-03, -2.45374718e-04,
#         -6.92418768e-06, -7.71715186e-05,  5.92862285e-05]),
#  array([-0.00077718, -0.00021311,  0.00447089,  0.00106164, -0.00359333,
#         -0.00173193, -0.00402307]),
#  array([1.66930896e-01, 4.82014139e-02, 8.81974887e-03, 1.94185495e-03,
#         4.89223190e-04, 1.21407697e-04, 3.08606198e-05]),
#  array([0.1669309 , 0.12020345, 0.10641201, 0.10193609, 0.10121467,
#         0.10325359, 0.1000628 ]))

# %%
import numpy as np
from mlmc.stoch_heat_eqn_qoi import stoch_heat_eqn_qoi
def nth_fourier_mode(n, u):
    # Calculates integral from 0 to 1 of 2*u(x,t)sin(n pi x) dx
    x = np.linspace(0, 1, u.shape[0])
    sin_basis = np.sin(n * np.pi * x)[:, np.newaxis]
    integrand = 2 * u * sin_basis
    fourier_mode = np.trapz(integrand, x, axis=0)
    return fourier_mode

first_fourier_var = lambda u: nth_fourier_mode(1, u)**2
true_var = lambda n: (1 - np.exp(- 2 * n**2 * np.pi**2 * 0.25)) / (n**2 * np.pi**2)

stoch_heat_eqn_qoi(qoi_fn=first_fourier_var, validation_value=true_var(1))
# Out:
# l = 0
# l = 1
# l = 2
# l = 3
# /var/folders/l5/rhh7z5c528b5hjwqy30m3vzr0000gn/T/ipykernel_7657/3994078466.py:8: DeprecationWarning: `trapz` is deprecated. Use `trapezoid` instead, or one of the numerical integration functions in `scipy.integrate`.
#   fourier_mode = np.trapz(integrand, x, axis=0)
# l = 4
# l = 5
# l = 6
# Estimates of key MLMC Theorem parameters based on linear regression:
# alpha = 2.048627 (exponent for MLMC weak convergence)
# beta = 2.037886 (exponent for MLMC variance)
# gamma = 2.950030 (exponent for MLMC cost
# eps = 0.005
# Adding new level 3 with remaining error 0.003776 > eps/sqrt(2) = 0.003536
# New level 3 added, with 187 samples and variance 0.000845
# eps = 0.01
# eps = 0.02
# eps = 0.05
# eps = 0.1
# (array([ 1.57853226e-01, -5.02232517e-02, -1.01550660e-02, -1.25075677e-03,
#         -2.82333043e-04, -7.44438352e-05, -3.43450286e-05]),
#  array([0.15785323, 0.11048084, 0.10450866, 0.10149774, 0.10038664,
#         0.09850028, 0.10100293]),
#  array([4.85089747e-02, 2.64817503e-02, 3.59766544e-03, 8.11757869e-04,
#         1.90193143e-04, 4.91283466e-05, 1.25240264e-05]),
#  array([0.04850897, 0.02419823, 0.02261846, 0.01969846, 0.02085095,
#         0.01937728, 0.01989401]))

# %%
# %%timeit
from mlmc.stoch_heat_eqn_qoi import stoch_heat_eqn_qoi
stoch_heat_eqn_qoi()
# Out:
# l = 0
# l = 1
# l = 2
# l = 3
# l = 4
# l = 5
# l = 6
# Estimates of key MLMC Theorem parameters based on linear regression:
# alpha = 0.516481 (exponent for MLMC weak convergence)
# beta = 2.138417 (exponent for MLMC variance)
# gamma = 2.956026 (exponent for MLMC cost
# eps = 0.005
# Adding new level 3 with remaining error 0.094341 > eps/sqrt(2) = 0.003536
# New level 3 added, with 74 samples and variance 0.000356
# Adding new level 4 with remaining error 0.014461 > eps/sqrt(2) = 0.003536
# New level 4 added, with 23 samples and variance 0.000103
# Adding new level 5 with remaining error 0.008877 > eps/sqrt(2) = 0.003536
# New level 5 added, with 5 samples and variance 0.000017
# Adding new level 6 with remaining error 0.005946 > eps/sqrt(2) = 0.003536
# New level 6 added, with 2 samples and variance 0.000005
# eps = 0.01
# Adding new level 3 with remaining error 0.095473 > eps/sqrt(2) = 0.007071
# New level 3 added, with 19 samples and variance 0.000366
# Adding new level 4 with remaining error 0.017107 > eps/sqrt(2) = 0.007071
# New level 4 added, with 6 samples and variance 0.000098
# Adding new level 5 with remaining error 0.013644 > eps/sqrt(2) = 0.007071
# New level 5 added, with 2 samples and variance 0.000021
# Adding new level 6 with remaining error 0.008576 > eps/sqrt(2) = 0.007071
# New level 6 added, with 1 samples and variance 0.000002
# eps = 0.02
# Adding new level 3 with remaining error 0.090059 > eps/sqrt(2) = 0.014142
# New level 3 added, with 4 samples and variance 0.000224
# eps = 0.05
# Adding new level 3 with remaining error 0.091813 > eps/sqrt(2) = 0.035355
# New level 3 added, with 1 samples and variance 0.000281
# eps = 0.1
# Adding new level 3 with remaining error 0.101956 > eps/sqrt(2) = 0.070711
# New level 3 added, with 1 samples and variance 0.000418
# l = 0
# l = 1
# l = 2
# l = 3
# l = 4
# l = 5
# l = 6
# Estimates of key MLMC Theorem parameters based on linear regression:
# alpha = 0.588454 (exponent for MLMC weak convergence)
# beta = 2.148900 (exponent for MLMC variance)
# gamma = 2.933054 (exponent for MLMC cost
# eps = 0.005
# Adding new level 3 with remaining error 0.073567 > eps/sqrt(2) = 0.003536
# New level 3 added, with 81 samples and variance 0.000395
# Adding new level 4 with remaining error 0.014235 > eps/sqrt(2) = 0.003536
# New level 4 added, with 21 samples and variance 0.000087
# Adding new level 5 with remaining error 0.007636 > eps/sqrt(2) = 0.003536
# New level 5 added, with 3 samples and variance 0.000009
# Adding new level 6 with remaining error 0.007312 > eps/sqrt(2) = 0.003536
# New level 6 added, with 1 samples and variance 0.000001
# Adding new level 7 with remaining error 0.004863 > eps/sqrt(2) = 0.003536
# New level 7 added, with 1 samples and variance 0.000000
# eps = 0.01
# Adding new level 3 with remaining error 0.078202 > eps/sqrt(2) = 0.007071
# New level 3 added, with 22 samples and variance 0.000411
# Adding new level 4 with remaining error 0.010572 > eps/sqrt(2) = 0.007071
# New level 4 added, with 5 samples and variance 0.000069
# Adding new level 5 with remaining error 0.012262 > eps/sqrt(2) = 0.007071
# New level 5 added, with 2 samples and variance 0.000021
# eps = 0.02
# Adding new level 3 with remaining error 0.079575 > eps/sqrt(2) = 0.014142
# New level 3 added, with 5 samples and variance 0.000385
# Adding new level 4 with remaining error 0.018578 > eps/sqrt(2) = 0.014142
# New level 4 added, with 1 samples and variance 0.000043
# eps = 0.05
# Adding new level 3 with remaining error 0.069973 > eps/sqrt(2) = 0.035355
# New level 3 added, with 2 samples and variance 0.000499
# eps = 0.1
# Adding new level 3 with remaining error 0.073861 > eps/sqrt(2) = 0.070711
# New level 3 added, with 1 samples and variance 0.000531
# l = 0
# l = 1
# l = 2
# l = 3
# l = 4
# l = 5
# l = 6
# Estimates of key MLMC Theorem parameters based on linear regression:
# alpha = 0.533764 (exponent for MLMC weak convergence)
# beta = 2.168837 (exponent for MLMC variance)
# gamma = 2.933891 (exponent for MLMC cost
# eps = 0.005
# Adding new level 3 with remaining error 0.089342 > eps/sqrt(2) = 0.003536
# New level 3 added, with 80 samples and variance 0.000388
# Adding new level 4 with remaining error 0.012337 > eps/sqrt(2) = 0.003536
# New level 4 added, with 19 samples and variance 0.000079
# Adding new level 5 with remaining error 0.012369 > eps/sqrt(2) = 0.003536
# New level 5 added, with 3 samples and variance 0.000010
# Adding new level 6 with remaining error 0.008544 > eps/sqrt(2) = 0.003536
# New level 6 added, with 1 samples and variance 0.000003
# Adding new level 7 with remaining error 0.005087 > eps/sqrt(2) = 0.003536
# New level 7 added, with 1 samples and variance 0.000000
# eps = 0.01
# Adding new level 3 with remaining error 0.092356 > eps/sqrt(2) = 0.007071
# New level 3 added, with 20 samples and variance 0.000374
# Adding new level 4 with remaining error 0.009927 > eps/sqrt(2) = 0.007071
# New level 4 added, with 6 samples and variance 0.000106
# eps = 0.02
# Adding new level 3 with remaining error 0.088769 > eps/sqrt(2) = 0.014142
# New level 3 added, with 5 samples and variance 0.000328
# Adding new level 4 with remaining error 0.014774 > eps/sqrt(2) = 0.014142
# New level 4 added, with 1 samples and variance 0.000036
# eps = 0.05
# Adding new level 3 with remaining error 0.099230 > eps/sqrt(2) = 0.035355
# New level 3 added, with 1 samples and variance 0.000303
# eps = 0.1
# Adding new level 3 with remaining error 0.084533 > eps/sqrt(2) = 0.070711
# New level 3 added, with 1 samples and variance 0.000466
# l = 0
# l = 1
# l = 2
# l = 3
# l = 4
# l = 5
# l = 6
# Estimates of key MLMC Theorem parameters based on linear regression:
# alpha = 0.569518 (exponent for MLMC weak convergence)
# beta = 2.167281 (exponent for MLMC variance)
# gamma = 2.976796 (exponent for MLMC cost
# eps = 0.005
# Adding new level 3 with remaining error 0.077941 > eps/sqrt(2) = 0.003536
# New level 3 added, with 66 samples and variance 0.000311
# Adding new level 4 with remaining error 0.011007 > eps/sqrt(2) = 0.003536
# New level 4 added, with 19 samples and variance 0.000079
# Adding new level 5 with remaining error 0.007894 > eps/sqrt(2) = 0.003536
# New level 5 added, with 4 samples and variance 0.000011
# Adding new level 6 with remaining error 0.005957 > eps/sqrt(2) = 0.003536
# New level 6 added, with 1 samples and variance 0.000001
# eps = 0.01
# Adding new level 3 with remaining error 0.077076 > eps/sqrt(2) = 0.007071
# New level 3 added, with 23 samples and variance 0.000456
# Adding new level 4 with remaining error 0.013849 > eps/sqrt(2) = 0.007071
# New level 4 added, with 4 samples and variance 0.000047
# Adding new level 5 with remaining error 0.009332 > eps/sqrt(2) = 0.007071
# New level 5 added, with 2 samples and variance 0.000019
# Adding new level 6 with remaining error 0.009972 > eps/sqrt(2) = 0.007071
# New level 6 added, with 1 samples and variance 0.000002
# eps = 0.02
# Adding new level 3 with remaining error 0.090441 > eps/sqrt(2) = 0.014142
# New level 3 added, with 5 samples and variance 0.000354
# eps = 0.05
# Adding new level 3 with remaining error 0.072659 > eps/sqrt(2) = 0.035355
# New level 3 added, with 1 samples and variance 0.000460
# eps = 0.1
# Adding new level 3 with remaining error 0.072691 > eps/sqrt(2) = 0.070711
# New level 3 added, with 1 samples and variance 0.000368
# l = 0
# l = 1
# l = 2
# l = 3
# l = 4
# l = 5
# l = 6
# Estimates of key MLMC Theorem parameters based on linear regression:
# alpha = 0.547382 (exponent for MLMC weak convergence)
# beta = 2.174829 (exponent for MLMC variance)
# gamma = 2.966616 (exponent for MLMC cost
# eps = 0.005
# Adding new level 3 with remaining error 0.085049 > eps/sqrt(2) = 0.003536
# New level 3 added, with 74 samples and variance 0.000356
# Adding new level 4 with remaining error 0.012001 > eps/sqrt(2) = 0.003536
# New level 4 added, with 20 samples and variance 0.000081
# Adding new level 5 with remaining error 0.008387 > eps/sqrt(2) = 0.003536
# New level 5 added, with 4 samples and variance 0.000012
# Adding new level 6 with remaining error 0.005873 > eps/sqrt(2) = 0.003536
# New level 6 added, with 2 samples and variance 0.000007
# eps = 0.01
# Adding new level 3 with remaining error 0.086854 > eps/sqrt(2) = 0.007071
# New level 3 added, with 19 samples and variance 0.000352
# Adding new level 4 with remaining error 0.018293 > eps/sqrt(2) = 0.007071
# New level 4 added, with 5 samples and variance 0.000081
# Adding new level 5 with remaining error 0.017532 > eps/sqrt(2) = 0.007071
# New level 5 added, with 2 samples and variance 0.000030
# Adding new level 6 with remaining error 0.012496 > eps/sqrt(2) = 0.007071
# New level 6 added, with 1 samples and variance 0.000006
# Adding new level 7 with remaining error 0.007151 > eps/sqrt(2) = 0.007071
# New level 7 added, with 1 samples and variance 0.000001
# eps = 0.02
# Adding new level 3 with remaining error 0.091937 > eps/sqrt(2) = 0.014142
# New level 3 added, with 5 samples and variance 0.000361
# Adding new level 4 with remaining error 0.016327 > eps/sqrt(2) = 0.014142
# New level 4 added, with 1 samples and variance 0.000040
# eps = 0.05
# Adding new level 3 with remaining error 0.053279 > eps/sqrt(2) = 0.035355
# New level 3 added, with 1 samples and variance 0.000318
# eps = 0.1
# Adding new level 3 with remaining error 0.086523 > eps/sqrt(2) = 0.070711
# New level 3 added, with 1 samples and variance 0.000324
# l = 0
# l = 1
# l = 2
# l = 3
# l = 4
# l = 5
# l = 6
# Estimates of key MLMC Theorem parameters based on linear regression:
# alpha = 0.623839 (exponent for MLMC weak convergence)
# beta = 2.157747 (exponent for MLMC variance)
# gamma = 2.975280 (exponent for MLMC cost
# eps = 0.005
# Adding new level 3 with remaining error 0.063768 > eps/sqrt(2) = 0.003536
# New level 3 added, with 84 samples and variance 0.000415
# Adding new level 4 with remaining error 0.011042 > eps/sqrt(2) = 0.003536
# New level 4 added, with 16 samples and variance 0.000060
# Adding new level 5 with remaining error 0.008454 > eps/sqrt(2) = 0.003536
# New level 5 added, with 5 samples and variance 0.000019
# Adding new level 6 with remaining error 0.005555 > eps/sqrt(2) = 0.003536
# New level 6 added, with 1 samples and variance 0.000002
# eps = 0.01
# Adding new level 3 with remaining error 0.064591 > eps/sqrt(2) = 0.007071
# New level 3 added, with 16 samples and variance 0.000282
# Adding new level 4 with remaining error 0.014179 > eps/sqrt(2) = 0.007071
# New level 4 added, with 4 samples and variance 0.000059
# Adding new level 5 with remaining error 0.008160 > eps/sqrt(2) = 0.007071
# New level 5 added, with 1 samples and variance 0.000012
# eps = 0.02
# Adding new level 3 with remaining error 0.065949 > eps/sqrt(2) = 0.014142
# New level 3 added, with 7 samples and variance 0.000508
# Adding new level 4 with remaining error 0.019850 > eps/sqrt(2) = 0.014142
# New level 4 added, with 2 samples and variance 0.000067
# eps = 0.05
# Adding new level 3 with remaining error 0.085718 > eps/sqrt(2) = 0.035355
# New level 3 added, with 1 samples and variance 0.000217
# Adding new level 4 with remaining error 0.044664 > eps/sqrt(2) = 0.035355
# New level 4 added, with 1 samples and variance 0.000024
# eps = 0.1
# l = 0
# l = 1
# l = 2
# l = 3
# l = 4
# l = 5
# l = 6
# Estimates of key MLMC Theorem parameters based on linear regression:
# alpha = 0.554956 (exponent for MLMC weak convergence)
# beta = 2.150522 (exponent for MLMC variance)
# gamma = 2.927965 (exponent for MLMC cost
# eps = 0.005
# Adding new level 3 with remaining error 0.083211 > eps/sqrt(2) = 0.003536
# New level 3 added, with 55 samples and variance 0.000249
# Adding new level 4 with remaining error 0.011637 > eps/sqrt(2) = 0.003536
# New level 4 added, with 19 samples and variance 0.000080
# Adding new level 5 with remaining error 0.004813 > eps/sqrt(2) = 0.003536
# New level 5 added, with 7 samples and variance 0.000028
# Adding new level 6 with remaining error 0.006810 > eps/sqrt(2) = 0.003536
# New level 6 added, with 2 samples and variance 0.000004
# Adding new level 7 with remaining error 0.004635 > eps/sqrt(2) = 0.003536
# New level 7 added, with 1 samples and variance 0.000000
# eps = 0.01
# Adding new level 3 with remaining error 0.086437 > eps/sqrt(2) = 0.007071
# New level 3 added, with 17 samples and variance 0.000306
# Adding new level 4 with remaining error 0.011830 > eps/sqrt(2) = 0.007071
# New level 4 added, with 4 samples and variance 0.000059
# Adding new level 5 with remaining error 0.011629 > eps/sqrt(2) = 0.007071
# New level 5 added, with 2 samples and variance 0.000028
# Adding new level 6 with remaining error 0.007835 > eps/sqrt(2) = 0.007071
# New level 6 added, with 1 samples and variance 0.000003
# eps = 0.02
# Adding new level 3 with remaining error 0.077519 > eps/sqrt(2) = 0.014142
# New level 3 added, with 5 samples and variance 0.000363
# eps = 0.05
# Adding new level 3 with remaining error 0.086204 > eps/sqrt(2) = 0.035355
# New level 3 added, with 1 samples and variance 0.000398
# eps = 0.1
# Adding new level 3 with remaining error 0.094329 > eps/sqrt(2) = 0.070711
# New level 3 added, with 1 samples and variance 0.000363
# l = 0
# l = 1
# l = 2
# l = 3
# l = 4
# l = 5
# l = 6
# Estimates of key MLMC Theorem parameters based on linear regression:
# alpha = 0.615877 (exponent for MLMC weak convergence)
# beta = 2.158687 (exponent for MLMC variance)
# gamma = 2.958396 (exponent for MLMC cost
# eps = 0.005
# Adding new level 3 with remaining error 0.066913 > eps/sqrt(2) = 0.003536
# New level 3 added, with 74 samples and variance 0.000358
# Adding new level 4 with remaining error 0.010306 > eps/sqrt(2) = 0.003536
# New level 4 added, with 17 samples and variance 0.000067
# Adding new level 5 with remaining error 0.006596 > eps/sqrt(2) = 0.003536
# New level 5 added, with 4 samples and variance 0.000012
# Adding new level 6 with remaining error 0.005655 > eps/sqrt(2) = 0.003536
# New level 6 added, with 2 samples and variance 0.000005
# Adding new level 7 with remaining error 0.003605 > eps/sqrt(2) = 0.003536
# New level 7 added, with 1 samples and variance 0.000001
# eps = 0.01
# Adding new level 3 with remaining error 0.067129 > eps/sqrt(2) = 0.007071
# New level 3 added, with 23 samples and variance 0.000452
# eps = 0.02
# Adding new level 3 with remaining error 0.077497 > eps/sqrt(2) = 0.014142
# New level 3 added, with 6 samples and variance 0.000393
# eps = 0.05
# Adding new level 3 with remaining error 0.067907 > eps/sqrt(2) = 0.035355
# New level 3 added, with 1 samples and variance 0.000390
# Adding new level 4 with remaining error 0.059159 > eps/sqrt(2) = 0.035355
# New level 4 added, with 1 samples and variance 0.000044
# Adding new level 5 with remaining error 0.038603 > eps/sqrt(2) = 0.035355
# New level 5 added, with 1 samples and variance 0.000005
# eps = 0.1
# 4min 47s ± 4.83 s per loop (mean ± std. dev. of 7 runs, 1 loop each)
